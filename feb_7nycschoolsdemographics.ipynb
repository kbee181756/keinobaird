# %% [markdown]
# <a href="https://colab.research.google.com/github/kbee181756/keinobaird/blob/master/feb_7nycschoolsdemographics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12fa2ecd-785b-440a-894c-92bae745f7e0" name="files[]" multiple disabled />
#      <output id="result-12fa2ecd-785b-440a-894c-92bae745f7e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving demographics.csv to demographics.csv

# %%
schools = pd.read_csv('demographics.csv')
schools.head()
# Out:
#       DBN                School Name  ... % Poverty  Economic Need Index
# 0  01M015  P.S. 015 Roberto Clemente  ...      90.0              No Data
# 1  01M015  P.S. 015 Roberto Clemente  ...      92.3               93.50%
# 2  01M015  P.S. 015 Roberto Clemente  ...      84.7               89.60%
# 3  01M015  P.S. 015 Roberto Clemente  ...      85.4               89.20%
# 4  01M015  P.S. 015 Roberto Clemente  ...      84.7               89.00%
#
# [5 rows x 39 columns]

# %%
schools2017_18 = schools[schools['Year'] == '2017-18']
schools2017_18.head()
# Out:
#        DBN                     School Name  ... % Poverty  Economic Need Index
# 4   01M015       P.S. 015 Roberto Clemente  ...      84.7               89.00%
# 9   01M019             P.S. 019 Asher Levy  ...      76.7               67.20%
# 14  01M020            P.S. 020 Anna Silver  ...      71.6               79.20%
# 19  01M034  P.S. 034 Franklin D. Roosevelt  ...      97.6               93.90%
# 24  01M063       The STAR Academy - P.S.63  ...      81.8               75.90%
#
# [5 rows x 39 columns]

# %%
def get_first_three(sequence):
  return sequence[:3]

# %%
schools2017_18['first_three'] = schools2017_18['DBN'].apply(get_first_three)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
schools2017_18.head()
# Out:
#        DBN                     School Name  ... Economic Need Index  first_three
# 4   01M015       P.S. 015 Roberto Clemente  ...              89.00%          01M
# 9   01M019             P.S. 019 Asher Levy  ...              67.20%          01M
# 14  01M020            P.S. 020 Anna Silver  ...              79.20%          01M
# 19  01M034  P.S. 034 Franklin D. Roosevelt  ...              93.90%          01M
# 24  01M063       The STAR Academy - P.S.63  ...              75.90%          01M
#
# [5 rows x 40 columns]

# %%
district_01m = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '01M'])

# %%
district_01m.shape
# Out:
# (29, 40)

# %%
district_01m.describe()
# Out:
#        Total Enrollment  Grade PK (Half Day & Full Day)  ...   # Poverty  % Poverty
# count         29.000000                       29.000000  ...   29.000000  29.000000
# mean         387.896552                       14.379310  ...  251.724138  73.527586
# std          299.408148                       14.714943  ...  111.131163  20.798522
# min          106.000000                        0.000000  ...   80.000000  22.800000
# 25%          241.000000                        0.000000  ...  166.000000  64.700000
# 50%          318.000000                       13.000000  ...  223.000000  81.800000
# 75%          433.000000                       30.000000  ...  331.000000  87.700000
# max         1734.000000                       36.000000  ...  462.000000  97.600000
#
# [8 rows x 35 columns]

# %%
district_01m.head()
# Out:
#        DBN                     School Name  ... Economic Need Index  first_three
# 4   01M015       P.S. 015 Roberto Clemente  ...              89.00%          01M
# 9   01M019             P.S. 019 Asher Levy  ...              67.20%          01M
# 14  01M020            P.S. 020 Anna Silver  ...              79.20%          01M
# 19  01M034  P.S. 034 Franklin D. Roosevelt  ...              93.90%          01M
# 24  01M063       The STAR Academy - P.S.63  ...              75.90%          01M
#
# [5 rows x 40 columns]

# %%
print(district_01m['Grade 1'].mean())
print(district_01m['Grade 2'].mean())
print(district_01m['Grade 3'].mean())
print(district_01m['Grade 4'].mean())
print(district_01m['Grade 5'].mean())
print(district_01m['Total Enrollment'].mean())
# Out:
# 29.17241379310345
# 29.448275862068964
# 29.724137931034484
# 28.93103448275862
# 28.03448275862069
# 387.8965517241379

# %%
district_02m = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '02M'])
print(district_02m['Grade 1'].mean())
print(district_02m['Grade 2'].mean())
print(district_02m['Grade 3'].mean())
print(district_02m['Grade 4'].mean())
print(district_02m['Grade 5'].mean())
print(district_02m['Total Enrollment'].mean())
# Out:
# 24.88235294117647
# 24.142857142857142
# 23.10924369747899
# 23.33613445378151
# 24.067226890756302
# 523.8655462184873

# %%
district_03m = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '03M'])
print(district_03m['Grade 1'].mean())
print(district_03m['Grade 2'].mean())
print(district_03m['Grade 3'].mean())
print(district_03m['Grade 4'].mean())
print(district_03m['Grade 5'].mean())
print(district_03m['Total Enrollment'].mean())
# Out:
# 30.844444444444445
# 32.044444444444444
# 31.933333333333334
# 31.133333333333333
# 30.244444444444444
# 491.5777777777778

# %%
district_04m = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '04M'])
print(district_04m['Grade 1'].mean())
print(district_04m['Grade 2'].mean())
print(district_04m['Grade 3'].mean())
print(district_04m['Grade 4'].mean())
print(district_04m['Grade 5'].mean())
print(district_04m['Total Enrollment'].mean())
# Out:
# 28.6875
# 30.5625
# 31.3125
# 30.9375
# 30.5625
# 397.65625

# %%
district_01m['Total Enrollment'].plot(kind='bar', figsize=(15, 7));
district_02m['Total Enrollment'].plot(kind='line', figsize=(15, 7));

# %%
plt.style.use('fivethirtyeight')

# %%
district_02m['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_02m['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_02m['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_02m['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 2')
plt.legend()
plt.show();

# %%
district_01m['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_01m['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_01m['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_01m['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 1')
plt.legend()
plt.show();

# %%
district_03m['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_03m['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_03m['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_03m['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 3')
plt.legend()
plt.show();

# %%
district_04m['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_04m['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_04m['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_04m['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 4')
plt.legend()
plt.show();

# %%
district_28q = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '28Q'])
print(district_28q['Grade 1'].mean())
print(district_28q['Grade 2'].mean())
print(district_28q['Grade 3'].mean())
print(district_28q['Grade 4'].mean())
print(district_28q['Grade 5'].mean())
print(district_28q['Total Enrollment'].mean())
# Out:
# 55.431372549019606
# 55.294117647058826
# 54.588235294117645
# 55.78431372549019
# 53.88235294117647
# 794.156862745098

# %%
district_28q['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_28q['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_28q['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_28q['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 28')
plt.legend()
plt.show();

# %%
district_28q['% Black'].plot(kind='density', figsize=(25, 7), color='black')
district_28q['% Hispanic'].plot(kind='density', figsize=(25, 7), color='red')
district_28q['% Asian'].plot(kind='density', figsize=(25, 7), color='yellow')
district_28q['% White'].plot(kind='density', figsize=(25, 7), color='white')
plt.title('District 28')
plt.legend()
plt.show();

# %%
district_28q['# Black'].plot(kind='density', figsize=(25, 7), color='black')
district_28q['# Hispanic'].plot(kind='density', figsize=(25, 7), color='red')
district_28q['# Asian'].plot(kind='density', figsize=(25, 7), color='yellow')
district_28q['# White'].plot(kind='density', figsize=(25, 7), color='white')
plt.title('District 28')
plt.legend()
plt.show();

# %%
district_19k = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '19K'])
print(district_19k['Grade 1'].mean())
print(district_19k['Grade 2'].mean())
print(district_19k['Grade 3'].mean())
print(district_19k['Grade 4'].mean())
print(district_19k['Grade 5'].mean())
print(district_19k['Total Enrollment'].mean())
# Out:
# 34.9375
# 36.458333333333336
# 35.541666666666664
# 38.229166666666664
# 37.583333333333336
# 443.5833333333333

# %%
district_19k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_19k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_19k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_19k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 19')
plt.legend()
plt.show();

# %%
district_17k = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '17K'])
print(district_17k['Grade 1'].mean())
print(district_17k['Grade 2'].mean())
print(district_17k['Grade 3'].mean())
print(district_17k['Grade 4'].mean())
print(district_17k['Grade 5'].mean())
print(district_17k['Total Enrollment'].mean())
# Out:
# 28.102040816326532
# 27.102040816326532
# 29.653061224489797
# 28.877551020408163
# 28.857142857142858
# 430.0612244897959

# %%
district_17k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_17k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_17k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_17k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 17')
plt.legend()
plt.show(); 
plt.show();

# %%
district_19k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_19k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_19k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_19k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 19')
plt.legend()
plt.show();

# %%
district_08x = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '08X'])
print(district_08x['Grade 1'].mean())
print(district_08x['Grade 2'].mean())
print(district_08x['Grade 3'].mean())
print(district_08x['Grade 4'].mean())
print(district_08x['Grade 5'].mean())
print(district_08x['Total Enrollment'].mean())
# Out:
# 37.50909090909091
# 39.69090909090909
# 40.18181818181818
# 38.945454545454545
# 40.14545454545455
# 494.8181818181818

# %%
district_08x['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_08x['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_08x['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_08x['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 8')
plt.legend()
plt.show();

# %%
district_09x = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '09X'])
print(district_09x['Grade 1'].mean())
print(district_09x['Grade 2'].mean())
print(district_09x['Grade 3'].mean())
print(district_09x['Grade 4'].mean())
print(district_09x['Grade 5'].mean())
print(district_09x['Total Enrollment'].mean())
# Out:
# 39.608695652173914
# 40.95652173913044
# 40.36231884057971
# 40.17391304347826
# 39.391304347826086
# 487.2608695652174

# %%
district_09x['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_09x['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_09x['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_09x['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 9')
plt.legend()
plt.show();

# %%
district_05m = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '05M'])
print(district_05m['Grade 1'].mean())
print(district_05m['Grade 2'].mean())
print(district_05m['Grade 3'].mean())
print(district_05m['Grade 4'].mean())
print(district_05m['Grade 5'].mean())
print(district_05m['Total Enrollment'].mean())
# Out:
# 25.103448275862068
# 25.96551724137931
# 27.75862068965517
# 28.586206896551722
# 27.06896551724138
# 379.0689655172414

# %%
district_05m['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_05m['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_05m['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_05m['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 5')
plt.legend()
plt.show();

# %%
district_20k = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '20K'])
print(district_20k['Grade 1'].mean())
print(district_20k['Grade 2'].mean())
print(district_20k['Grade 3'].mean())
print(district_20k['Grade 4'].mean())
print(district_20k['Grade 5'].mean())
print(district_20k['Total Enrollment'].mean())
# Out:
# 95.77272727272727
# 90.93181818181819
# 95.93181818181819
# 91.0909090909091
# 92.97727272727273
# 1164.4545454545455

# %%
district_20k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_20k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_20k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_20k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 20')
plt.legend()
plt.show();

# %%
district_15k = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '15K'])
print(district_15k['Grade 1'].mean())
print(district_15k['Grade 2'].mean())
print(district_15k['Grade 3'].mean())
print(district_15k['Grade 4'].mean())
print(district_15k['Grade 5'].mean())
print(district_15k['Total Enrollment'].mean())
# Out:
# 62.775510204081634
# 61.265306122448976
# 61.38775510204081
# 60.30612244897959
# 59.42857142857143
# 647.3265306122449

# %%
district_15k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_15k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_15k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_15k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 15')
plt.legend()
plt.show();

# %%
district_21k = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '21K'])
print(district_21k['Grade 1'].mean())
print(district_21k['Grade 2'].mean())
print(district_21k['Grade 3'].mean())
print(district_21k['Grade 4'].mean())
print(district_21k['Grade 5'].mean())
print(district_21k['Total Enrollment'].mean())
# Out:
# 53.34146341463415
# 53.951219512195124
# 55.78048780487805
# 54.65853658536585
# 54.21951219512195
# 863.3658536585366

# %%
district_21k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_21k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_21k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_21k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 21')
plt.legend()
plt.show();

# %%
district_22k = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '22K'])
print(district_22k['Grade 1'].mean())
print(district_22k['Grade 2'].mean())
print(district_22k['Grade 3'].mean())
print(district_22k['Grade 4'].mean())
print(district_22k['Grade 5'].mean())
print(district_22k['Total Enrollment'].mean())
# Out:
# 64.0
# 66.16666666666667
# 67.23809523809524
# 66.71428571428571
# 68.30952380952381
# 812.7619047619048

# %%
district_22k['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_22k['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_22k['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_22k['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 22')
plt.legend()
plt.show();

# %%
district_27q = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '27Q'])
print(district_27q['Grade 1'].mean())
print(district_27q['Grade 2'].mean())
print(district_27q['Grade 3'].mean())
print(district_27q['Grade 4'].mean())
print(district_27q['Grade 5'].mean())
print(district_27q['Total Enrollment'].mean())
# Out:
# 53.98412698412698
# 54.01587301587302
# 56.74603174603175
# 56.095238095238095
# 58.74603174603175
# 685.936507936508

# %%
district_27q['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_27q['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_27q['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_27q['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 27')
plt.legend()
plt.show();

# %%
district_30q = pd.DataFrame(schools2017_18[schools2017_18['first_three'] == '30Q'])
print(district_30q['Grade 1'].mean())
print(district_30q['Grade 2'].mean())
print(district_30q['Grade 3'].mean())
print(district_30q['Grade 4'].mean())
print(district_30q['Grade 5'].mean())
print(district_30q['Total Enrollment'].mean())
# Out:
# 61.0
# 62.0
# 61.08163265306123
# 60.10204081632653
# 64.10204081632654
# 801.8775510204082

# %%
district_30q['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_30q['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_30q['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_30q['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 30')
plt.legend()
plt.show();

# %%
district_27q['# Black'].plot(kind='density', figsize=(25, 7), color='black')
district_27q['# Hispanic'].plot(kind='density', figsize=(25, 7), color='red')
district_27q['# Asian'].plot(kind='density', figsize=(25, 7), color='yellow')
district_27q['# White'].plot(kind='density', figsize=(25, 7), color='white')
plt.title('District 27')
plt.legend()
plt.show();

# %%
legend = ['d28', 'd30', 'd19', 'd17', 'd21', 'd1', 'd3', 'd9', 'd8']

# %%
district_28q['% Poverty'].plot(kind='density', figsize=(25, 7), color='green')
district_30q['% Poverty'].plot(kind='density', figsize=(25, 7), color='green')
district_19k['% Poverty'].plot(kind='density', figsize=(25, 7), color='purple')
district_17k['% Poverty'].plot(kind='density', figsize=(25, 7), color='purple')
district_21k['% Poverty'].plot(kind='density', figsize=(25, 7), color='purple')
district_01m['% Poverty'].plot(kind='density', figsize=(25, 7), color='blue')
district_03m['% Poverty'].plot(kind='density', figsize=(25, 7), color='blue')
district_09x['% Poverty'].plot(kind='density', figsize=(25, 7), color='red')
district_08x['% Poverty'].plot(kind='density', figsize=(25, 7), color='red')
plt.title('% Poverty')
plt.legend(legend)
plt.show();

# %%
district_28q['% Poverty'].plot(kind='density', figsize=(25, 7), color='green')
district_30q['% Poverty'].plot(kind='density', figsize=(25, 7), color='blue')
plt.title('% Poverty - Queens')
plt.legend(legend)
plt.show();

# %%
legend_bk = ['d19', 'd17', 'd21']

# %%
district_19k['% Poverty'].plot(kind='density', figsize=(25, 7), color='red')
district_17k['% Poverty'].plot(kind='density', figsize=(25, 7), color='yellow')
district_21k['% Poverty'].plot(kind='density', figsize=(25, 7), color='green')
plt.title('% Poverty - Brooklyn')
plt.legend(legend_bk)
plt.show();

# %%
district_01m['% Poverty'].plot(kind='density', figsize=(25, 7), color='blue')
district_03m['% Poverty'].plot(kind='density', figsize=(25, 7), color='blue')
district_09x['% Poverty'].plot(kind='density', figsize=(25, 7), color='red')
district_08x['% Poverty'].plot(kind='density', figsize=(25, 7), color='red')
plt.title('% Poverty')
plt.legend(legend)
plt.show();

# %%
district_01m.head()
# Out:
#        DBN                     School Name  ... Economic Need Index  first_three
# 4   01M015       P.S. 015 Roberto Clemente  ...              89.00%          01M
# 9   01M019             P.S. 019 Asher Levy  ...              67.20%          01M
# 14  01M020            P.S. 020 Anna Silver  ...              79.20%          01M
# 19  01M034  P.S. 034 Franklin D. Roosevelt  ...              93.90%          01M
# 24  01M063       The STAR Academy - P.S.63  ...              75.90%          01M
#
# [5 rows x 40 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a4bf065-5b11-4794-99a3-552c6da867d5" name="files[]" multiple disabled />
#      <output id="result-7a4bf065-5b11-4794-99a3-552c6da867d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LocationMaster.csv to LocationMaster.csv

# %%
location_master = pd.read_csv('LocationMaster.csv')

# %%
location_master.head()
# Out:
#   ATS System Code Location Code  ... Unnamed: 43  Unnamed: 44
# 0          01M015          M015  ...         NaN          NaN
# 1          01M019          M019  ...         NaN          NaN
# 2          01M020          M020  ...         NaN          NaN
# 3          01M034          M034  ...         NaN          NaN
# 4          01M063          M063  ...         NaN          NaN
#
# [5 rows x 45 columns]

# %%
updated_lc_masters = pd.DataFrame(location_master.drop(['Unnamed: 21', 
                      'Unnamed: 22',
                      'Unnamed: 23',
                      'Unnamed: 24',
                      'Unnamed: 25',
                      'Unnamed: 26',
                      'Unnamed: 27',
                      'Unnamed: 28',
                      'Unnamed: 29',
                      'Unnamed: 30',
                      'Unnamed: 31',
                      'Unnamed: 32',
                      'Unnamed: 33',
                      'Unnamed: 34',
                      'Unnamed: 35',
                      'Unnamed: 36',
                      'Unnamed: 37',
                      'Unnamed: 38',
                      'Unnamed: 39', 
                      'Unnamed: 40',
                      'Unnamed: 41',
                      'Unnamed: 42',
                      'Unnamed: 43',
                      'Unnamed: 44',
                      'Status Description',
                      'Building Code',
                      'Managed By Name',
                      'Location Code',
                      'BEDS Number',
                      'Location Type Description',
                      'Grades Final',
                      'Administrative District Location Code',
                      'Administrative District Name'], axis = 1))

# %%
updated_lc_masters.head()
# Out:
#   ATS System Code  ... Administrative District Code
# 0          01M015  ...                            1
# 1          01M019  ...                            1
# 2          01M020  ...                            1
# 3          01M034  ...                            1
# 4          01M063  ...                            1
#
# [5 rows x 12 columns]

# %%
def get_first_three_lc(sequence):
  return sequence[:3]

# %%
updated_lc_masters['first_three_1'] = updated_lc_masters['ATS System Code'].apply(get_first_three)

# %%
updated_lc_masters.head()
# Out:
#   ATS System Code  ... first_three_1
# 0          01M015  ...           01M
# 1          01M019  ...           01M
# 2          01M020  ...           01M
# 3          01M034  ...           01M
# 4          01M063  ...           01M
#
# [5 rows x 13 columns]

# %%
district_01m_loc = pd.DataFrame(updated_lc_masters[updated_lc_masters['first_three_1'] == '01M'])

# %%
district_01m_loc.head()
# Out:
#   ATS System Code  ... first_three_1
# 0          01M015  ...           01M
# 1          01M019  ...           01M
# 2          01M020  ...           01M
# 3          01M034  ...           01M
# 4          01M063  ...           01M
#
# [5 rows x 13 columns]

# %%
district_01m.head()
# Out:
#        DBN                     School Name  ... Economic Need Index  first_three
# 4   01M015       P.S. 015 Roberto Clemente  ...              89.00%          01M
# 9   01M019             P.S. 019 Asher Levy  ...              67.20%          01M
# 14  01M020            P.S. 020 Anna Silver  ...              79.20%          01M
# 19  01M034  P.S. 034 Franklin D. Roosevelt  ...              93.90%          01M
# 24  01M063       The STAR Academy - P.S.63  ...              75.90%          01M
#
# [5 rows x 40 columns]

# %%
district_one = pd.DataFrame(pd.merge(district_01m, district_01m_loc, left_on='School Name', right_on='Location Name'))

# %%
district_one.head(20)
# Out:
#        DBN  ... first_three_1
# 0   01M015  ...           01M
# 1   01M019  ...           01M
# 2   01M020  ...           01M
# 3   01M034  ...           01M
# 4   01M064  ...           01M
# 5   01M110  ...           01M
# 6   01M134  ...           01M
# 7   01M140  ...           01M
# 8   01M142  ...           01M
# 9   01M184  ...           01M
# 10  01M188  ...           01M
# 11  01M301  ...           01M
# 12  01M315  ...           01M
# 13  01M332  ...           01M
# 14  01M361  ...           01M
# 15  01M363  ...           01M
# 16  01M364  ...           01M
# 17  01M378  ...           01M
# 18  01M448  ...           01M
# 19  01M450  ...           01M
#
# [20 rows x 53 columns]

# %%
district_1_elementary = pd.DataFrame(district_one[district_one['Location Category Description'] == 'Elementary'])

# %%
district_1_elementary.head()
# Out:
#       DBN  ... first_three_1
# 0  01M015  ...           01M
# 1  01M019  ...           01M
# 2  01M020  ...           01M
# 4  01M064  ...           01M
# 6  01M134  ...           01M
#
# [5 rows x 53 columns]

# %%
district_1_elementary = pd.DataFrame(district_1_elementary[district_1_elementary['first_three_1'] == '01M'])
print(district_1_elementary['Grade PK (Half Day & Full Day)'].mean())
print(district_1_elementary['Grade 1'].mean())
print(district_1_elementary['Grade 2'].mean())
print(district_1_elementary['Grade 3'].mean())
print(district_1_elementary['Grade 4'].mean())
print(district_1_elementary['Grade 5'].mean())
print(district_1_elementary['Total Enrollment'].mean())
# Out:
# 27.6
# 49.3
# 47.1
# 48.4
# 46.8
# 44.1
# 311.8

# %%
district_1_elementary['# Black'].plot(kind='density', figsize=(25, 7), color='black')
district_1_elementary['# Hispanic'].plot(kind='density', figsize=(25, 7), color='red')
district_1_elementary['# Asian'].plot(kind='density', figsize=(25, 7), color='yellow')
district_1_elementary['# White'].plot(kind='density', figsize=(25, 7), color='white')
plt.title('District 1: Elementary')
plt.legend()
plt.show();

# %%
district_01m_loc

# %%
district_1_elementary['% Black'].plot(kind='line', figsize=(25, 7), color='black')
district_1_elementary['% Hispanic'].plot(kind='line', figsize=(25, 7), color='red')
district_1_elementary['% Asian'].plot(kind='line', figsize=(25, 7), color='yellow')
district_1_elementary['% White'].plot(kind='line', figsize=(25, 7), color='white')
plt.title('District 1: Elementary')
plt.legend()
plt.show();
